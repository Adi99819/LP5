# %%
from tensorflow.keras.datasets import imdb
import numpy as np

# %%
# Load dataset
(train_data, train_label), (test_data, test_label) = imdb.load_data(num_words=10000)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step

# %%
# Convert reviews into vectors
def vectorize_sequences(sequences, dimensions=10000):
    results = np.zeros((len(sequences), dimensions))

    for i, sequence in enumerate(sequences):
        results[i, sequence] = 1

    return results

# %%
# Vectorized input data
x_train = vectorize_sequences(train_data)
x_test = vectorize_sequences(test_data)

# %%
# Labels
y_train = np.asarray(train_label).astype('float32')
y_test = np.asarray(test_label).astype('float32')

# %%
# Build model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
model = Sequential()

# Hidden layers
model.add(Dense(16, input_shape=(10000,), activation='relu'))
model.add(Dense(16, activation='relu'))
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Output layer
model.add(Dense(1, activation='sigmoid'))

# %%
# Compile model
model.compile(
    optimizer='adam',
    loss='binary_crossentropy',
    metrics=['accuracy']
)

# %%
# Model summary
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 16)             │       160,016 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 16)             │           272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 160,305 (626.19 KB)
#  Trainable params: 160,305 (626.19 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Train model
history = model.fit(
    x_train,
    y_train,
    validation_split=0.3,
    epochs=20,
    verbose=1,
    batch_size=512
)
# Out:
# Epoch 1/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 9s 201ms/step - accuracy: 0.7790 - loss: 0.5654 - val_accuracy: 0.8733 - val_loss: 0.3952
# Epoch 2/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 72ms/step - accuracy: 0.9027 - loss: 0.2998 - val_accuracy: 0.8941 - val_loss: 0.2830
# Epoch 3/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - accuracy: 0.9313 - loss: 0.2029 - val_accuracy: 0.8929 - val_loss: 0.2719
# Epoch 4/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9491 - loss: 0.1561 - val_accuracy: 0.8916 - val_loss: 0.2755
# Epoch 5/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 34ms/step - accuracy: 0.9639 - loss: 0.1225 - val_accuracy: 0.8895 - val_loss: 0.2925
# Epoch 6/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - accuracy: 0.9730 - loss: 0.0982 - val_accuracy: 0.8839 - val_loss: 0.3151
# Epoch 7/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - accuracy: 0.9804 - loss: 0.0792 - val_accuracy: 0.8836 - val_loss: 0.3419
# Epoch 8/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9861 - loss: 0.0627 - val_accuracy: 0.8803 - val_loss: 0.3741
# Epoch 9/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 38ms/step - accuracy: 0.9904 - loss: 0.0493 - val_accuracy: 0.8753 - val_loss: 0.4075
# Epoch 10/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9931 - loss: 0.0400 - val_accuracy: 0.8724 - val_loss: 0.4393
# Epoch 11/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.9955 - loss: 0.0314 - val_accuracy: 0.8713 - val_loss: 0.4721
# Epoch 12/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9974 - loss: 0.0249 - val_accuracy: 0.8707 - val_loss: 0.5050
# Epoch 13/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9981 - loss: 0.0197 - val_accuracy: 0.8685 - val_loss: 0.5350
# Epoch 14/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9990 - loss: 0.0157 - val_accuracy: 0.8685 - val_loss: 0.5645
# Epoch 15/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - accuracy: 0.9993 - loss: 0.0129 - val_accuracy: 0.8676 - val_loss: 0.5924
# Epoch 16/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - accuracy: 0.9995 - loss: 0.0106 - val_accuracy: 0.8665 - val_loss: 0.6164
# Epoch 17/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 2s 41ms/step - accuracy: 0.9996 - loss: 0.0089 - val_accuracy: 0.8661 - val_loss: 0.6392
# Epoch 18/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 31ms/step - accuracy: 0.9996 - loss: 0.0075 - val_accuracy: 0.8663 - val_loss: 0.6617
# Epoch 19/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - accuracy: 0.9997 - loss: 0.0064 - val_accuracy: 0.8653 - val_loss: 0.6832
# Epoch 20/20
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.9997 - loss: 0.0057 - val_accuracy: 0.8649 - val_loss: 0.7032

# %%
# Evaluate model
results = model.evaluate(x_test, y_test)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.8528 - loss: 0.7681

# %%
print("Test Loss:", results[0])
print("Test Accuracy:", results[1])
# Out:
# Test Loss: 0.7680986523628235
# Test Accuracy: 0.8528000116348267
